# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1=pd.read_csv("5_OneCatSevNumOrdered.csv")

# %%
df1.head()
# Out:
#    year sex     name    n      prop
# 0  1880   F    Helen  636  0.006516
# 1  1880   F   Amanda  241  0.002469
# 2  1880   F    Betty  117  0.001199
# 3  1880   F  Dorothy  112  0.001147
# 4  1880   F    Linda   27  0.000277

# %%
df1=pd.pivot(df1, index="year", columns="name", values="prop")

df1=df1.fillna(method="ffill")
df1=df1.fillna(method="bfill")
df1.head()
# Out:
# name    Amanda    Ashley     Betty   Deborah   Dorothy     Helen   Jessica  \
# year
# 1880  0.002469  0.000004  0.001199  0.000123  0.001147  0.006516  0.000072
# 1881  0.002660  0.000004  0.001133  0.000142  0.001103  0.006191  0.000071
# 1882  0.002489  0.000004  0.001063  0.000130  0.000994  0.007243  0.000069
# 1883  0.002390  0.000004  0.001000  0.000133  0.001174  0.007180  0.000050
# 1884  0.002449  0.000004  0.001047  0.000094  0.001185  0.007166  0.000102
#
# name     Linda  Patricia
# year
# 1880  0.000277  0.000044
# 1881  0.000384  0.000044
# 1882  0.000311  0.000044
# 1883  0.000408  0.000044
# 1884  0.000240  0.000044

# %%
x=df1.iloc[:,[i for i in range(len(df1.columns))]]
sns.lineplot(data=x)
# Out:
# <AxesSubplot: xlabel='year'>
