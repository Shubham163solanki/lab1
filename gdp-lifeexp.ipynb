# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df1=pd.read_csv("4_ThreeNum.csv")
df1=df1.sort_values("pop")
df1.head()
# Out:
#                    country continent  lifeExp     pop     gdpPercap
# 108  Sao Tome and Principe    Africa   65.528  199579   1598.435089
# 57                 Iceland    Europe   81.757  301931  36180.789190
# 35                Djibouti    Africa   54.791  496374   2082.481567
# 40       Equatorial Guinea    Africa   51.579  551201  12154.089750
# 84              Montenegro    Europe   74.543  684736   9253.896111

# %%
plt.figure(figsize=(10,5))
x=df1["gdpPercap"]
# plt.xticks(rotation=-90,ha="left")
y=df1["lifeExp"]
sns.scatterplot(x,y,size=df1["pop"])
# Out:
# c:\anaconda\envs\tf-gpu\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: xlabel='gdpPercap', ylabel='lifeExp'>
