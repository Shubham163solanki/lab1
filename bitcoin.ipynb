# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df1=pd.read_csv("3_TwoNumOrdered.csv")
df1=df1.dropna()
df1.head()
# Out:
#           date value
# 0  2013-04-28 135.98
# 1  2013-04-29 147.49
# 2  2013-04-30 146.93
# 3  2013-05-01 139.89
# 4   2013-05-02 125.6

# %%
x=df1["date value"].values
x=np.array([i.split() for i in x])

# %%
date=x[:,0]
value=x[:,1]
date_time = pd.to_datetime(date)

# %%
value=[float(i) for i in value]
value
df1=pd.DataFrame({"date":pd.to_datetime(date),"value":value})

# %%
plt.plot(df1["date"],df1["value"])

# %% [markdown]
# area chart

# %%
plt.stackplot(df1["date"],df1["value"])

# %% [markdown]
# when we have few points

# %%
df2=df1[:10]
plt.xticks(rotation=-45,ha='left')
plt.scatter(df2["date"],df2["value"])
plt.plot(df2["date"],df2["value"])

# %%
plt.xticks(rotation=-45,ha='left')
plt.ylim(100,150)
# plt.scatter(df2["date"],df2["value"])
plt.stackplot(df2["date"],df2["value"])

# %% [markdown]
# compartision with a limit(let the limit be 120)

# %%
x_linespace=np.datetime_data
